# %%
import pandas as pd

# %%
df=pd.read_csv("deneme1.csv",sep=";")

# %%
df
# Out:
#    id  student_id    name  surname  location
# 0   1      432454   Ahmet    Cevik  Istanbul
# 1   2      435243     Ali   Yilmaz    Ankara
# 2   3      894795   Feyza  Testere  Istanbul
# 3   4      764282  Mehmet   Varsiz     Adana
# 4   5      554645   Zehra    Gunes   Karabuk

# %%
students=[
    {"name":"Ahmet","surname":"Cevik","email":"ahmet@gmail.com"},
    {"name":"Mehmet","surname":"Varsiz","email":"mehmet@gmail.com"}
]

# %%
df=pd.DataFrame(students)

# %%
df
# Out:
#      name surname             email
# 0   Ahmet   Cevik   ahmet@gmail.com
# 1  Mehmet  Varsiz  mehmet@gmail.com

# %%
students={
    "name":["Ahmet","Mehmet","Ali"],
    "surname":["Cevik","Varsiz","Yilmaz"],
    "email":["ahmet@gmail.com","mehmet@gmail.com","ali@gmail.com"]
}

# %%
df=pd.DataFrame(students)

# %%
df
# Out:
#      name surname             email
# 0   Ahmet   Cevik   ahmet@gmail.com
# 1  Mehmet  Varsiz  mehmet@gmail.com
# 2     Ali  Yilmaz     ali@gmail.com

# %%
df['surname']
# Out:
# 0     Cevik
# 1    Varsiz
# 2    Yilmaz
# Name: surname, dtype: object

# %%
type(df['surname'])
# Out:
# pandas.core.series.Series

# %%
df[['name','surname']]
# Out:
#      name surname
# 0   Ahmet   Cevik
# 1  Mehmet  Varsiz
# 2     Ali  Yilmaz

# %%
df.columns
# Out:
# Index(['name', 'surname', 'email'], dtype='object')

# %%
list(df.columns)
# Out:
# ['name', 'surname', 'email']

# %%
df.columns.tolist()
# Out:
# ['name', 'surname', 'email']

# %%
df['email']
# Out:
# 0     ahmet@gmail.com
# 1    mehmet@gmail.com
# 2       ali@gmail.com
# Name: email, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.iloc[1]
# Out:
# name                 Mehmet
# surname              Varsiz
# email      mehmet@gmail.com
# Name: 1, dtype: object

# %%
df.iloc[2]['name']
# Out:
# 'Ali'

# %%
df.loc[1]
# Out:
# name                 Mehmet
# surname              Varsiz
# email      mehmet@gmail.com
# Name: 1, dtype: object

# %%
df.index=df.index+5

# %%
df
# Out:
#       name surname             email
# 10   Ahmet   Cevik   ahmet@gmail.com
# 11  Mehmet  Varsiz  mehmet@gmail.com
# 12     Ali  Yilmaz     ali@gmail.com

# %%
df.iloc[1]
# Out:
# name                 Mehmet
# surname              Varsiz
# email      mehmet@gmail.com
# Name: 11, dtype: object

# %%
df.loc[1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: range.index(x): x not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.loc[1]
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexing.py:1432, in _LocIndexer._getitem_axis(self, key, axis)
#    1430 # fall thru to straight lookup
#    1431 self._validate_key(key, axis)
# -> 1432 return self._get_label(key, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexing.py:1382, in _LocIndexer._get_label(self, label, axis)
#    1380 def _get_label(self, label, axis: AxisInt):
#    1381     # GH#5567 this will fail if the label is not present in the axis.
# -> 1382     return self.obj.xs(label, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/generic.py:4323, in NDFrame.xs(self, key, axis, level, drop_level)
#    4321             new_index = index[loc]
#    4322 else:
# -> 4323     loc = index.get_loc(key)
#    4325     if isinstance(loc, np.ndarray):
#    4326         if loc.dtype == np.bool_:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexes/range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: 1

# %%
df.loc[10]
# Out:
# name                 Ahmet
# surname              Cevik
# email      ahmet@gmail.com
# Name: 10, dtype: object

# %%
df.shape
# Out:
# (3, 3)
