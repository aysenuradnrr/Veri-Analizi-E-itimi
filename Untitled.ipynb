# %%
import pandas as pd

# %%
df=pd.read_csv("Salary_Data.csv")

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     42.0    Male         Bachelor's      Software Engineer
# 1     38.0  Female           Master's           Data Analyst
# 2     55.0    Male                PhD         Senior Manager
# 3     46.0  Female         Bachelor's        Sales Associate
# 4     62.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  59.0  Female                PhD  Director of Marketing
# 6700  42.0    Male        High School        Sales Associate
# 6701  40.0  Female  Bachelor's Degree      Financial Manager
# 6702  56.0    Male    Master's Degree      Marketing Manager
# 6703  36.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                    15.0   90000.0
# 1                    13.0   65000.0
# 2                    55.0  150000.0
# 3                    47.0   60000.0
# 4                    60.0  200000.0
# ...

# %%
df['Gender']==  'Male'
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 6699    False
# 6700     True
# 6701    False
# 6702     True
# 6703    False
# Name: Gender, Length: 6704, dtype: bool

# %%
gender_filter=df['Gender']== 'Male' #Mask

# %%
df[gender_filter]
# Out:
#        Age Gender    Education Level                    Job Title  \
# 0     32.0   Male         Bachelor's            Software Engineer
# 2     45.0   Male                PhD               Senior Manager
# 4     52.0   Male           Master's                     Director
# 5     29.0   Male         Bachelor's            Marketing Analyst
# 7     31.0   Male         Bachelor's                Sales Manager
# ...    ...    ...                ...                          ...
# 6694  27.0   Male        High School    Digital Marketing Manager
# 6696  28.0   Male                PhD         Sales Representative
# 6698  37.0   Male  Bachelor's Degree  Junior Sales Representative
# 6700  32.0   Male        High School              Sales Associate
# 6702  46.0   Male    Master's Degree            Marketing Manager
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 2                    15.0  150000.0
# 4                    20.0  200000.0
# ...

# %%
df[df['Gender']== 'Male']
# Out:
#        Age Gender    Education Level                    Job Title  \
# 0     32.0   Male         Bachelor's            Software Engineer
# 2     45.0   Male                PhD               Senior Manager
# 4     52.0   Male           Master's                     Director
# 5     29.0   Male         Bachelor's            Marketing Analyst
# 7     31.0   Male         Bachelor's                Sales Manager
# ...    ...    ...                ...                          ...
# 6694  27.0   Male        High School    Digital Marketing Manager
# 6696  28.0   Male                PhD         Sales Representative
# 6698  37.0   Male  Bachelor's Degree  Junior Sales Representative
# 6700  32.0   Male        High School              Sales Associate
# 6702  46.0   Male    Master's Degree            Marketing Manager
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 2                    15.0  150000.0
# 4                    20.0  200000.0
# ...

# %%
df[df['Job Title'] == 'Software Engineer']
# Out:
#        Age  Gender    Education Level          Job Title  Years of Experience  \
# 0     32.0    Male         Bachelor's  Software Engineer                  5.0
# 376   28.0  Female         Bachelor's  Software Engineer                  3.0
# 380   29.0  Female         Bachelor's  Software Engineer                  4.0
# 384   31.0  Female         Bachelor's  Software Engineer                  6.0
# 388   29.0  Female         Bachelor's  Software Engineer                  4.0
# ...    ...     ...                ...                ...                  ...
# 6191  27.0    Male  Bachelor's Degree  Software Engineer                  3.0
# 6205  27.0    Male  Bachelor's Degree  Software Engineer                  3.0
# 6219  27.0    Male  Bachelor's Degree  Software Engineer                  3.0
# 6233  27.0    Male  Bachelor's Degree  Software Engineer                  3.0
# 6247  27.0    Male  Bachelor's Degree  Software Engineer                  3.0
#
#         Salary
# 0      90000.0
# ...

# %%
df[ (df['Job Title'] == 'Software Engineer') & (df['Gender'] =='Female')]
# Out:
#        Age  Gender    Education Level          Job Title  Years of Experience  \
# 376   28.0  Female         Bachelor's  Software Engineer                  3.0
# 380   29.0  Female         Bachelor's  Software Engineer                  4.0
# 384   31.0  Female         Bachelor's  Software Engineer                  6.0
# 388   29.0  Female         Bachelor's  Software Engineer                  4.0
# 392   31.0  Female         Bachelor's  Software Engineer                  6.0
# ...    ...     ...                ...                ...                  ...
# 3380  30.0  Female  Bachelor's Degree  Software Engineer                  5.0
# 4396  31.0  Female  Bachelor's Degree  Software Engineer                  5.0
# 5885  32.0  Female    Master's Degree  Software Engineer                  9.0
# 6012  33.0  Female    Master's Degree  Software Engineer                  8.0
# 6133  26.0  Female    Master's Degree  Software Engineer                  2.0
#
#         Salary
# 376   125000.0
# ...

# %%
df['Job Title']
# Out:
# 0           Software Engineer
# 1                Data Analyst
# 2              Senior Manager
# 3             Sales Associate
# 4                    Director
#                 ...
# 6699    Director of Marketing
# 6700          Sales Associate
# 6701        Financial Manager
# 6702        Marketing Manager
# 6703          Sales Executive
# Name: Job Title, Length: 6704, dtype: object

# %%
df[(df['Job Title'] == 'Software Engineer') |(df['Education Level'] == "Master's Degree") ]
# Out:
#        Age  Gender  Education Level                         Job Title  \
# 0     32.0    Male       Bachelor's                 Software Engineer
# 376   28.0  Female       Bachelor's                 Software Engineer
# 380   29.0  Female       Bachelor's                 Software Engineer
# 384   31.0  Female       Bachelor's                 Software Engineer
# 388   29.0  Female       Bachelor's                 Software Engineer
# ...    ...     ...              ...                               ...
# 6683  51.0  Female  Master's Degree         Content Marketing Manager
# 6688  46.0    Male  Master's Degree             Director of Marketing
# 6693  43.0  Female  Master's Degree                     Sales Manager
# 6697  51.0  Female  Master's Degree  Senior Product Marketing Manager
# 6702  46.0    Male  Master's Degree                 Marketing Manager
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 376                   3.0  125000.0
# ...

# %%
df[~(df['Job Title'] == 'Software Engineer')] # not
# Out:
#        Age  Gender    Education Level              Job Title  \
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# 5     29.0    Male         Bachelor's      Marketing Analyst
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# 5                     2.0   55000.0
# ...

# %%
df[df['Job Title'].isin(['Data Analyst','Director','Financial Manager'])]
# Out:
#        Age  Gender    Education Level          Job Title  Years of Experience  \
# 1     28.0  Female           Master's       Data Analyst                  3.0
# 4     52.0    Male           Master's           Director                 20.0
# 24    41.0    Male           Master's  Financial Manager                 13.0
# 81    41.0  Female           Master's       Data Analyst                 13.0
# 378   27.0  Female         Bachelor's       Data Analyst                  2.0
# ...    ...     ...                ...                ...                  ...
# 6645  30.0  Female  Bachelor's Degree  Financial Manager                  4.0
# 6662  42.0    Male  Bachelor's Degree  Financial Manager                 13.0
# 6673  30.0  Female  Bachelor's Degree  Financial Manager                  4.0
# 6690  42.0    Male  Bachelor's Degree  Financial Manager                 13.0
# 6701  30.0  Female  Bachelor's Degree  Financial Manager                  4.0
#
#         Salary
# 1      65000.0
# ...

# %%
df.at[0,'Job Title']= None

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's                   None
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.at[1,'Job Title'] = pd.NA

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's                   None
# 1     28.0  Female           Master's                   <NA>
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's                   None
# 1     28.0  Female           Master's                   <NA>
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df[df['Job Title'].str.contains('Manager',na=False)]
# Out:
#        Age  Gender    Education Level                         Job Title  \
# 2     45.0    Male                PhD                    Senior Manager
# 6     42.0  Female           Master's                   Product Manager
# 7     31.0    Male         Bachelor's                     Sales Manager
# 11    48.0  Female         Bachelor's                        HR Manager
# 13    40.0  Female           Master's                   Project Manager
# ...    ...     ...                ...                               ...
# 6694  27.0    Male        High School         Digital Marketing Manager
# 6695  33.0  Female  Bachelor's Degree         Content Marketing Manager
# 6697  51.0  Female    Master's Degree  Senior Product Marketing Manager
# 6701  30.0  Female  Bachelor's Degree                 Financial Manager
# 6702  46.0    Male    Master's Degree                 Marketing Manager
#
#       Years of Experience    Salary
# 2                    15.0  150000.0
# ...

# %%
df[df['Job Title'].str.contains('Manager',na=True)]
# Out:
#        Age  Gender    Education Level                         Job Title  \
# 0     32.0    Male         Bachelor's                              None
# 1     28.0  Female           Master's                              <NA>
# 2     45.0    Male                PhD                    Senior Manager
# 6     42.0  Female           Master's                   Product Manager
# 7     31.0    Male         Bachelor's                     Sales Manager
# ...    ...     ...                ...                               ...
# 6694  27.0    Male        High School         Digital Marketing Manager
# 6695  33.0  Female  Bachelor's Degree         Content Marketing Manager
# 6697  51.0  Female    Master's Degree  Senior Product Marketing Manager
# 6701  30.0  Female  Bachelor's Degree                 Financial Manager
# 6702  46.0    Male    Master's Degree                 Marketing Manager
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# ...

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df[df['Age'] >=30]
# Out:
#        Age  Gender    Education Level                    Job Title  \
# 0     32.0    Male         Bachelor's            Software Engineer
# 2     45.0    Male                PhD               Senior Manager
# 3     36.0  Female         Bachelor's              Sales Associate
# 4     52.0    Male           Master's                     Director
# 6     42.0  Female           Master's              Product Manager
# ...    ...     ...                ...                          ...
# 6698  37.0    Male  Bachelor's Degree  Junior Sales Representative
# 6699  49.0  Female                PhD        Director of Marketing
# 6700  32.0    Male        High School              Sales Associate
# 6701  30.0  Female  Bachelor's Degree            Financial Manager
# 6702  46.0    Male    Master's Degree            Marketing Manager
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# ...

# %%
df[ (df['Age'] >=30) & (df['Age'] <=40) ]
# Out:
#        Age  Gender    Education Level                    Job Title  \
# 0     32.0    Male         Bachelor's            Software Engineer
# 3     36.0  Female         Bachelor's              Sales Associate
# 7     31.0    Male         Bachelor's                Sales Manager
# 9     38.0    Male                PhD             Senior Scientist
# 12    35.0    Male         Bachelor's            Financial Analyst
# ...    ...     ...                ...                          ...
# 6691  36.0  Female                PhD            Marketing Manager
# 6695  33.0  Female  Bachelor's Degree    Content Marketing Manager
# 6698  37.0    Male  Bachelor's Degree  Junior Sales Representative
# 6700  32.0    Male        High School              Sales Associate
# 6701  30.0  Female  Bachelor's Degree            Financial Manager
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 3                     7.0   60000.0
# 7                     4.0   80000.0
# ...

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.sort_values('Age')
# Out:
#        Age  Gender Education Level                    Job Title  \
# 4988  21.0  Female     High School  Junior Sales Representative
# 5122  21.0  Female     High School  Junior Sales Representative
# 5109  21.0  Female     High School  Junior Sales Representative
# 5096  21.0  Female     High School  Junior Sales Representative
# 4884  21.0  Female     High School  Junior Sales Representative
# ...    ...     ...             ...                          ...
# 1225  62.0    Male             PhD    Software Engineer Manager
# 1304  62.0    Male             PhD    Software Engineer Manager
# 1305  62.0    Male             PhD    Software Engineer Manager
# 172    NaN     NaN             NaN                          NaN
# 260    NaN     NaN             NaN                          NaN
#
#       Years of Experience    Salary
# 4988                  0.0   25000.0
# 5122                  0.0   25000.0
# 5109                  0.0   25000.0
# 5096                  0.0   25000.0
# ...

# %%
df.sort_values('Age',ascending=False) #artarak değil azalarak getir demek
# Out:
#        Age  Gender Education Level                    Job Title  \
# 1305  62.0    Male             PhD    Software Engineer Manager
# 1304  62.0    Male             PhD    Software Engineer Manager
# 1258  62.0    Male             PhD    Software Engineer Manager
# 1225  62.0    Male             PhD    Software Engineer Manager
# 1236  62.0    Male             PhD    Software Engineer Manager
# ...    ...     ...             ...                          ...
# 5044  21.0  Female     High School  Junior Sales Representative
# 4897  21.0  Female     High School  Junior Sales Representative
# 4962  21.0  Female     High School  Junior Sales Representative
# 172    NaN     NaN             NaN                          NaN
# 260    NaN     NaN             NaN                          NaN
#
#       Years of Experience    Salary
# 1305                 19.0  200000.0
# 1304                 20.0  200000.0
# 1258                 19.0  200000.0
# 1225                 19.0  200000.0
# ...

# %%
df.sort_values('Age',ascending=False,na_position='first')# boş satırları en başa koy demek
# Out:
#        Age  Gender Education Level                    Job Title  \
# 172    NaN     NaN             NaN                          NaN
# 260    NaN     NaN             NaN                          NaN
# 1305  62.0    Male             PhD    Software Engineer Manager
# 1304  62.0    Male             PhD    Software Engineer Manager
# 1258  62.0    Male             PhD    Software Engineer Manager
# ...    ...     ...             ...                          ...
# 5096  21.0  Female     High School  Junior Sales Representative
# 5083  21.0  Female     High School  Junior Sales Representative
# 5044  21.0  Female     High School  Junior Sales Representative
# 4897  21.0  Female     High School  Junior Sales Representative
# 4962  21.0  Female     High School  Junior Sales Representative
#
#       Years of Experience    Salary
# 172                   NaN       NaN
# 260                   NaN       NaN
# 1305                 19.0  200000.0
# 1304                 20.0  200000.0
# ...

# %%
df.sort_values('Age',ascending=False,inplace=True) #dataframein güncel halini böyle yaptım

# %%
df
# Out:
#        Age  Gender Education Level                    Job Title  \
# 1305  62.0    Male             PhD    Software Engineer Manager
# 1304  62.0    Male             PhD    Software Engineer Manager
# 1258  62.0    Male             PhD    Software Engineer Manager
# 1225  62.0    Male             PhD    Software Engineer Manager
# 1236  62.0    Male             PhD    Software Engineer Manager
# ...    ...     ...             ...                          ...
# 5044  21.0  Female     High School  Junior Sales Representative
# 4897  21.0  Female     High School  Junior Sales Representative
# 4962  21.0  Female     High School  Junior Sales Representative
# 172    NaN     NaN             NaN                          NaN
# 260    NaN     NaN             NaN                          NaN
#
#       Years of Experience    Salary
# 1305                 19.0  200000.0
# 1304                 20.0  200000.0
# 1258                 19.0  200000.0
# 1225                 19.0  200000.0
# ...

# %%
df.sort_values(['Age','Years of Experience'],ascending=[False,False])
# hem yaşı hem de çalışma yılını azalana göre sıralamasını istedik
# Out:
#        Age  Gender Education Level                    Job Title  \
# 1236  62.0    Male             PhD    Software Engineer Manager
# 1304  62.0    Male             PhD    Software Engineer Manager
# 1225  62.0    Male             PhD    Software Engineer Manager
# 1258  62.0    Male             PhD    Software Engineer Manager
# 1305  62.0    Male             PhD    Software Engineer Manager
# ...    ...     ...             ...                          ...
# 5096  21.0  Female     High School  Junior Sales Representative
# 5109  21.0  Female     High School  Junior Sales Representative
# 5122  21.0  Female     High School  Junior Sales Representative
# 172    NaN     NaN             NaN                          NaN
# 260    NaN     NaN             NaN                          NaN
#
#       Years of Experience    Salary
# 1236                 20.0  200000.0
# 1304                 20.0  200000.0
# 1225                 19.0  200000.0
# 1258                 19.0  200000.0
# ...

# %%
df.sort_values(['Age','Years of Experience'],ascending=[True,False] )
#yaş artarak sıralansın çalışma yılı da azalarak sıralansın
# Out:
#        Age  Gender Education Level                    Job Title  \
# 4884  21.0  Female     High School  Junior Sales Representative
# 4897  21.0  Female     High School  Junior Sales Representative
# 4910  21.0  Female     High School  Junior Sales Representative
# 4923  21.0  Female     High School  Junior Sales Representative
# 4936  21.0  Female     High School  Junior Sales Representative
# ...    ...     ...             ...                          ...
# 1225  62.0    Male             PhD    Software Engineer Manager
# 1258  62.0    Male             PhD    Software Engineer Manager
# 1305  62.0    Male             PhD    Software Engineer Manager
# 172    NaN     NaN             NaN                          NaN
# 260    NaN     NaN             NaN                          NaN
#
#       Years of Experience    Salary
# 4884                  0.0   25000.0
# 4897                  0.0   25000.0
# 4910                  0.0   25000.0
# 4923                  0.0   25000.0
# ...

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.sort_index()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.sort_index(ascending=False)
# Out:
#        Age  Gender    Education Level              Job Title  \
# 6703  26.0  Female        High School        Sales Executive
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6700  32.0    Male        High School        Sales Associate
# 6699  49.0  Female                PhD  Director of Marketing
# ...    ...     ...                ...                    ...
# 4     52.0    Male           Master's               Director
# 3     36.0  Female         Bachelor's        Sales Associate
# 2     45.0    Male                PhD         Senior Manager
# 1     28.0  Female           Master's           Data Analyst
# 0     32.0    Male         Bachelor's      Software Engineer
#
#       Years of Experience    Salary
# 6703                  1.0   35000.0
# 6702                 14.0  140000.0
# 6701                  4.0   55000.0
# 6700                  3.0   50000.0
# 6699                 20.0  200000.0
# ...

# %%
df.nlargest(10,'Salary')
#maaşı en yüksek 10 satır
# Out:
#        Age Gender    Education Level                 Job Title  \
# 30    50.0   Male         Bachelor's                       CEO
# 83    52.0   Male                PhD  Chief Technology Officer
# 5001  45.0   Male  Bachelor's Degree         Financial Manager
# 4276  51.0   Male                PhD            Data Scientist
# 4291  51.0   Male                PhD            Data Scientist
# 4306  51.0   Male                PhD            Data Scientist
# 4321  51.0   Male                PhD            Data Scientist
# 4336  51.0   Male                PhD            Data Scientist
# 4351  51.0   Male                PhD            Data Scientist
# 4366  51.0   Male                PhD            Data Scientist
#
#       Years of Experience    Salary
# 30                   25.0  250000.0
# 83                   24.0  250000.0
# 5001                 21.0  250000.0
# 4276                 24.0  240000.0
# 4291                 24.0  240000.0
# 4306                 24.0  240000.0
# ...

# %%
df.nsmallest(10,'Salary')
#maaşı en düşük 10 satır
# Out:
#        Age  Gender    Education Level                           Job Title  \
# 259   29.0    Male         Bachelor's  Junior Business Operations Analyst
# 4633  31.0  Female  Bachelor's Degree               Junior HR Coordinator
# 1890  25.0  Female  Bachelor's Degree                 Front end Developer
# 2654  23.0    Male                PhD           Software Engineer Manager
# 3893  22.0    Male        High School              Junior Sales Associate
# 3906  29.0  Female        High School              Junior Sales Associate
# 3921  29.0  Female        High School              Junior Sales Associate
# 3936  29.0  Female        High School              Junior Sales Associate
# 3951  29.0  Female        High School              Junior Sales Associate
# 3966  29.0  Female        High School              Junior Sales Associate
#
#       Years of Experience   Salary
# 259                   1.5    350.0
# 4633                  4.0    500.0
# 1890                  1.0    550.0
# ...

# %%
df=df.nsmallest(10,'Salary')

# %%
df
# Out:
#        Age  Gender    Education Level                           Job Title  \
# 259   29.0    Male         Bachelor's  Junior Business Operations Analyst
# 4633  31.0  Female  Bachelor's Degree               Junior HR Coordinator
# 1890  25.0  Female  Bachelor's Degree                 Front end Developer
# 2654  23.0    Male                PhD           Software Engineer Manager
# 3893  22.0    Male        High School              Junior Sales Associate
# 3906  29.0  Female        High School              Junior Sales Associate
# 3921  29.0  Female        High School              Junior Sales Associate
# 3936  29.0  Female        High School              Junior Sales Associate
# 3951  29.0  Female        High School              Junior Sales Associate
# 3966  29.0  Female        High School              Junior Sales Associate
#
#       Years of Experience   Salary
# 259                   1.5    350.0
# 4633                  4.0    500.0
# 1890                  1.0    550.0
# ...

# %%
df.reset_index()
# Out:
#    index   Age  Gender    Education Level                           Job Title  \
# 0    259  29.0    Male         Bachelor's  Junior Business Operations Analyst
# 1   4633  31.0  Female  Bachelor's Degree               Junior HR Coordinator
# 2   1890  25.0  Female  Bachelor's Degree                 Front end Developer
# 3   2654  23.0    Male                PhD           Software Engineer Manager
# 4   3893  22.0    Male        High School              Junior Sales Associate
# 5   3906  29.0  Female        High School              Junior Sales Associate
# 6   3921  29.0  Female        High School              Junior Sales Associate
# 7   3936  29.0  Female        High School              Junior Sales Associate
# 8   3951  29.0  Female        High School              Junior Sales Associate
# 9   3966  29.0  Female        High School              Junior Sales Associate
#
#    Years of Experience   Salary
# 0                  1.5    350.0
# 1                  4.0    500.0
# ...

# %%
df.reset_index(drop=True)
#indexler gözükmesin istediğim için ekledim
# Out:
#     Age  Gender    Education Level                           Job Title  \
# 0  29.0    Male         Bachelor's  Junior Business Operations Analyst
# 1  31.0  Female  Bachelor's Degree               Junior HR Coordinator
# 2  25.0  Female  Bachelor's Degree                 Front end Developer
# 3  23.0    Male                PhD           Software Engineer Manager
# 4  22.0    Male        High School              Junior Sales Associate
# 5  29.0  Female        High School              Junior Sales Associate
# 6  29.0  Female        High School              Junior Sales Associate
# 7  29.0  Female        High School              Junior Sales Associate
# 8  29.0  Female        High School              Junior Sales Associate
# 9  29.0  Female        High School              Junior Sales Associate
#
#    Years of Experience   Salary
# 0                  1.5    350.0
# 1                  4.0    500.0
# 2                  1.0    550.0
# 3                  1.0    579.0
# ...

# %%
df.head(20)
# Out:
#      Age  Gender Education Level              Job Title  Years of Experience  \
# 0   32.0    Male      Bachelor's      Software Engineer                  5.0
# 1   28.0  Female        Master's           Data Analyst                  3.0
# 2   45.0    Male             PhD         Senior Manager                 15.0
# 3   36.0  Female      Bachelor's        Sales Associate                  7.0
# 4   52.0    Male        Master's               Director                 20.0
# 5   29.0    Male      Bachelor's      Marketing Analyst                  2.0
# 6   42.0  Female        Master's        Product Manager                 12.0
# 7   31.0    Male      Bachelor's          Sales Manager                  4.0
# 8   26.0  Female      Bachelor's  Marketing Coordinator                  1.0
# 9   38.0    Male             PhD       Senior Scientist                 10.0
# 10  29.0    Male        Master's     Software Developer                  3.0
# ...

# %%
df.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6702.000000          6701.000000    6699.000000
# mean     33.620859             8.094687  115326.964771
# std       7.614633             6.059003   52786.183911
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
df['Age'].median() #ortanca yaşı veriyo
# Out:
# np.float64(32.0)

# %%
df['Age'].mean() #yaş ortalamasını veriyo
# Out:
# np.float64(33.62085944494181)

# %%
df['Age'].min()
# Out:
# np.float64(21.0)

# %%
df['Age'].max()
# Out:
# np.float64(62.0)

# %%
df['Age'].std() #yaşların standart sapması
# Out:
# np.float64(7.614632626251303)

# %%
df.head(5)
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df['Gender'].value_counts() # gender kolonunda olan şeylerin kaç tane olduğuu verir
# Out:
# Gender
# Male      3674
# Female    3014
# Other       14
# Name: count, dtype: int64

# %%
df['Gender'].value_counts() ['Male'] # gender kolonunda kaç tane male olduğunu verir
# Out:
# np.int64(3674)

# %%
df['Education Level'].value_counts(normalize=True) 
# çalışanların mezun olduğu yerlerin 0-1 arasına göre değerini veriyo,örneğin üniversite
# mezunu olanların sayısı yüzle çarparsak %33 olur
# Out:
# Education Level
# Bachelor's Degree    0.338308
# Master's Degree      0.234741
# PhD                  0.204149
# Bachelor's           0.112819
# High School          0.066856
# Master's             0.042979
# phD                  0.000149
# Name: proportion, dtype: float64

# %%
df['Salary'].sum() #salaryde olan bütün sayıları toplar
# Out:
# np.float64(772575337.0)

# %%
df.groupby('Job Title')['Salary'].mean()
# tüm meslekleri kendi gurplarına ayırıp hepsinin tek tek maaş ortalamasını hesapladı
# Out:
# Job Title
# Account Manager              75000.000000
# Accountant                   55000.000000
# Administrative Assistant     50000.000000
# Back end Developer          102352.561475
# Business Analyst             77500.000000
#                                 ...
# UX Designer                  80000.000000
# UX Researcher                65000.000000
# VP of Finance               200000.000000
# VP of Operations            190000.000000
# Web Developer                66436.781609
# Name: Salary, Length: 193, dtype: float64

# %%
df['Age']=df['Age'] +10 #tüm yaşlara 10 ekledik

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     42.0    Male         Bachelor's      Software Engineer
# 1     38.0  Female           Master's           Data Analyst
# 2     55.0    Male                PhD         Senior Manager
# 3     46.0  Female         Bachelor's        Sales Associate
# 4     62.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  59.0  Female                PhD  Director of Marketing
# 6700  42.0    Male        High School        Sales Associate
# 6701  40.0  Female  Bachelor's Degree      Financial Manager
# 6702  56.0    Male    Master's Degree      Marketing Manager
# 6703  36.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df['Years of Experience']=df['Years of Experience'].apply(lambda x: x+10)
# tecrübeli yıl sayılarını 10 arttırdı bunu apply ile yaptık

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     42.0    Male         Bachelor's      Software Engineer
# 1     38.0  Female           Master's           Data Analyst
# 2     55.0    Male                PhD         Senior Manager
# 3     46.0  Female         Bachelor's        Sales Associate
# 4     62.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  59.0  Female                PhD  Director of Marketing
# 6700  42.0    Male        High School        Sales Associate
# 6701  40.0  Female  Bachelor's Degree      Financial Manager
# 6702  56.0    Male    Master's Degree      Marketing Manager
# 6703  36.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                    15.0   90000.0
# 1                    13.0   65000.0
# 2                    45.0  150000.0
# 3                    37.0   60000.0
# 4                    50.0  200000.0
# ...

# %%
df['Years of Experience']=df['Years of Experience'].apply(lambda x: x+10 if x>15 else x)
# yine tecrübeli yıl sayısını 10 arttıracak ama tecrübe yılı 15 yıldan büyük olduğunda
# yapacak. Apply in avanatajı bu şart ekleyebiliyoruz

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     42.0    Male         Bachelor's      Software Engineer
# 1     38.0  Female           Master's           Data Analyst
# 2     55.0    Male                PhD         Senior Manager
# 3     46.0  Female         Bachelor's        Sales Associate
# 4     62.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  59.0  Female                PhD  Director of Marketing
# 6700  42.0    Male        High School        Sales Associate
# 6701  40.0  Female  Bachelor's Degree      Financial Manager
# 6702  56.0    Male    Master's Degree      Marketing Manager
# 6703  36.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                    15.0   90000.0
# 1                    13.0   65000.0
# 2                    55.0  150000.0
# 3                    47.0   60000.0
# 4                    60.0  200000.0
# ...

# %%
df.groupby("Job Title")["Salary"].mean()
# Out:
# Job Title
# Account Manager              75000.000000
# Accountant                   55000.000000
# Administrative Assistant     50000.000000
# Back end Developer          102352.561475
# Business Analyst             77500.000000
#                                 ...
# UX Designer                  80000.000000
# UX Researcher                65000.000000
# VP of Finance               200000.000000
# VP of Operations            190000.000000
# Web Developer                66436.781609
# Name: Salary, Length: 193, dtype: float64

# %%
salary_df=df.groupby("Job Title")["Salary"].mean()
# yeni bir dataframe oluşturduk

# %%
salary_df.reset_index()
# Out:
#                     Job Title         Salary
# 0             Account Manager   75000.000000
# 1                  Accountant   55000.000000
# 2    Administrative Assistant   50000.000000
# 3          Back end Developer  102352.561475
# 4            Business Analyst   77500.000000
# ..                        ...            ...
# 188               UX Designer   80000.000000
# 189             UX Researcher   65000.000000
# 190             VP of Finance  200000.000000
# 191          VP of Operations  190000.000000
# 192             Web Developer   66436.781609
#
# [193 rows x 2 columns]

# %%
salary_df.plot(x='Job Title',y='Salary')
# Out:
# <Axes: xlabel='Job Title'>

# %%
salary_df.sort_values(ascending=False).head(5)
# Out:
# Job Title
# CEO                         250000.000000
# Chief Technology Officer    250000.000000
# Chief Data Officer          220000.000000
# Director of Data Science    204561.403509
# VP of Finance               200000.000000
# Name: Salary, dtype: float64

# %%
salary_df.sort_values(ascending=False).head(5).plot(x="Job Title",y="Salary")
# Out:
# <Axes: xlabel='Job Title'>

# %%
salary_df.sort_values(ascending=False).head(5).plot(x="Job Title",y="Salary",kind="bar")
# kind sayasinde grafiğin tipini belirleyebiliriz
# Out:
# <Axes: xlabel='Job Title'>

# %%
salary_df.sort_values(ascending=False).head(20).plot(x="Job Title",y="Salary",kind="barh")
# Out:
# <Axes: ylabel='Job Title'>
